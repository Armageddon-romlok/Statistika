# %%
import pandas as pd
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %% [markdown]
# ## **Memuat dataset**

# %%
df = pd.read_csv('insurance.csv')

# %% [markdown]
# # **Menampilkan 5 data teratas**

# %%
display(df.head())
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # **1. Uji perbedaan Rata-rata Berdasarkan Jenis Kelamin**

# %%
# Memisahkan data charges untuk laki-laki dan perempuan
male_charges = df[df['sex'] == 'male']['charges']
female_charges = df[df['sex'] == 'female']['charges']

# Melakukan Independent T-Test
t_stat, p_val_sex = stats.ttest_ind(male_charges, female_charges)

print(f"Rata-rata Biaya Laki-laki   : ${male_charges.mean():.2f}")
print(f"Rata-rata Biaya Perempuan : ${female_charges.mean():.2f}")
print(f"T-statistic : {t_stat:.4f}")
print(f"P-value     : {p_val_sex:.4f}\n")

if p_val_reg < 0.05:
    print("Kesimpulan: Terdapat perbedaan rata-rata biaya klaim asuransi yang SIGNIFIKAN di antara keempat wilayah.")
else:
    print("Kesimpulan: Tidak terdapat perbedaan biaya klaim asuransi yang signifikan di antara keempat wilayah.")
# Out:
# Rata-rata Biaya Laki-laki   : $13956.75
# Rata-rata Biaya Perempuan : $12569.58
# T-statistic : 2.0975
# P-value     : 0.0361
#
# Kesimpulan: Terdapat perbedaan rata-rata biaya klaim asuransi yang SIGNIFIKAN di antara keempat wilayah.

# %% [markdown]
# # **2. Uji Perbedaan Rata-rata Berdasarkan Wilayah**

# %%
# Mengambil nilai unik dari kolom wilayah
regions = df['region'].unique()

# Menampilkan rata-rata per wilayah
for r in regions:
    mean_charge = df[df['region'] == r]['charges'].mean()
    print(f"Rata-rata Biaya {r.capitalize():<10} : ${mean_charge:.2f}")

# Menyiapkan list data charges per wilayah untuk uji ANOVA
region_data = [df[df['region'] == r]['charges'] for r in regions]

# Melakukan One-Way ANOVA
f_stat_reg, p_val_reg = stats.f_oneway(*region_data)

print(f"\nF-statistic : {f_stat_reg:.4f}")
print(f"P-value     : {p_val_reg:.4f}\n")

if p_val_interaction < 0.05:
    print("Kesimpulan: Terdapat efek interaksi yang SIGNIFIKAN antara jenis kelamin dan wilayah terhadap biaya klaim.")
else:
    print("Kesimpulan: TIDAK terdapat efek interaksi yang signifikan antara jenis kelamin dan wilayah.")
# Out:
# Rata-rata Biaya Southwest  : $12346.94
# Rata-rata Biaya Southeast  : $14735.41
# Rata-rata Biaya Northwest  : $12417.58
# Rata-rata Biaya Northeast  : $13406.38
#
# F-statistic : 2.9696
# P-value     : 0.0309
#
# Kesimpulan: TIDAK terdapat efek interaksi yang signifikan antara jenis kelamin dan wilayah.

# %% [markdown]
# #3. **Uji Efek Interaksi Jenis Kelamin dan Wilayah**

# %%
# Membuat model regresi linear (OLS) dengan variabel interaksi jenis kelamin dan wilayah
model = ols('charges ~ C(sex) + C(region) + C(sex):C(region)', data=df).fit()

# Menghasilkan tabel ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)
display(anova_table)

# Mengambil nilai p-value khusus untuk interaksi antara jenis kelamin dan wilayah
p_val_interaction = anova_table.loc['C(sex):C(region)', 'PR(>F)']
print(f"\nP-value Interaksi (Jenis Kelamin : Wilayah) : {p_val_interaction:.4f}\n")

if p_val_interaction < 0.05:
    print("Kesimpulan: Terdapat efek interaksi yang SIGNIFIKAN antara jenis kelamin dan wilayah terhadap biaya klaim.")
else:
    print("Kesimpulan: TIDAK terdapat efek interaksi yang signifikan antara jenis kelamin dan wilayah.")
# Out:
#                         sum_sq      df         F    PR(>F)
# C(sex)            6.130692e+08     1.0  4.206899  0.040455
# C(region)         1.270239e+09     3.0  2.905472  0.033691
# C(sex):C(region)  3.401733e+08     3.0  0.778093  0.506208
# Residual          1.938202e+11  1330.0       NaN       NaN
# P-value Interaksi (Jenis Kelamin : Wilayah) : 0.5062
#
# Kesimpulan: TIDAK terdapat efek interaksi yang signifikan antara jenis kelamin dan wilayah.
